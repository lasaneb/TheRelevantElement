# %%
# Initial Imports

import os
from newsapi import NewsApiClient
from datetime import date, timedelta
import pandas as pd
import pdfkit
import flair

news_api_key = os.getenv("news_api_key")

# %%
def top_headlines():
    newsapi = NewsApiClient(api_key=news_api_key)
    top_articles = newsapi.get_top_headlines(country="us", language='en')

    return top_articles

# %%
top_headlines_df = pd.DataFrame.from_dict(top_headlines()['articles'])

# %%
top_headlines_df
# Out:
#                                                source  \
# 0                        {'id': 'cnn', 'name': 'CNN'}
# 1                        {'id': 'cnn', 'name': 'CNN'}
# 2              {'id': None, 'name': 'New York Times'}
# 3                    {'id': None, 'name': 'BBC News'}
# 4              {'id': 'the-hill', 'name': 'The Hill'}
# 5                        {'id': None, 'name': 'ESPN'}
# 6              {'id': 'fox-news', 'name': 'Fox News'}
# 7                   {'id': None, 'name': 'AnandTech'}
# 8   {'id': 'the-wall-street-journal', 'name': 'The...
# 9                        {'id': None, 'name': 'CNBC'}
# 10              {'id': None, 'name': 'New York Post'}
# 11                 {'id': None, 'name': 'Daily Mail'}
# 12              {'id': None, 'name': 'New York Post'}
# 13             {'id': 'politico', 'name': 'Politico'}
# 14              {'id': None, 'name': 'New York Post'}
# 15               {'id': 'polygon', 'name': 'Polygon'}
# 16        {'id': None, 'name': 'Yahoo Entertainment'}
# 17  {'id': 'the-washington-post', 'name': 'The Was...
# 18               {'id': None, 'name': 'Fox Business'}
# 19                       {'id': 'cnn', 'name': 'CNN'}
#
#                                                author  \
# 0        Clare Foran, Ted Barrett and Ali Zaslav, CNN
# 1   By <a href="/profiles/tara-john">Tara John</a>...
# 2   Jonah E. Bromwich, Benjamin Protess, William K...
# 3                    https://www.facebook.com/bbcnews
# 4                                       Niall Stanage
# 5                                                None
# 6                                         Ryan Gaydos
# 7                                     Dr. Ian Cutress
# 8                                       Dave Michaels
# 9                                     Spencer Kimball
# 10                                   Jaclyn Hendricks
# 11                                        Ronny Reyes
# 12                         Ben Kesslen, Ben Feuerherd
# 13                                               None
# 14                               Evan Simko-Bednarski
# 15                                   Nicole Carpenter
# 16                                 Alexandra Semenova
# 17                                         Amy B Wang
# 18                                  Daniella Genovese
# 19                       Matt McFarland, CNN Business
#
#                                                 title  \
# 0   Senate passes stopgap bill to avert shutdown a...
# 1   The latest on the Ukraine-Russia border crisis...
# 2   N.Y. Attorney General Can Question Trump and 2...
# 3   Canada protests: Police warn Ottawa truckers o...
# 4   The Memo: Risks grow for Biden as Ukraine cris...
# 5   Los Angeles Rams, Matthew Stafford, wife Kelly...
# 6   Russian coach critical of Kamila Valieva after...
# 7   Intel Discloses Multi-Generation Xeon Scalable...
# 8   Tesla Tells Federal Judge That SEC Is Harassin...
# 9   California lays out plan to live with Covid fo...
# 10  Aaron Rodgers trolled by Bears legend Dick But...
# 3   https://ichef.bbci.co.uk/news/1024/branded_new...  2022-02-17T23:44:02Z
# 4   https://thehill.com/sites/default/files/articl...  2022-02-17T23:17:27Z
# 5   https://a4.espncdn.com/combiner/i?img=%2Fphoto...  2022-02-17T22:49:53Z
# 6   https://static.foxnews.com/foxnews.com/content...  2022-02-17T22:34:51Z
# 7   https://images.anandtech.com/doci/17259/Xeon2_...  2022-02-17T22:30:00Z
# 8             https://images.wsj.net/im-487930/social  2022-02-17T22:17:00Z
# 9   https://image.cnbcfm.com/api/v1/image/10697638...  2022-02-17T22:01:18Z
# 10  https://nypost.com/wp-content/uploads/sites/2/...  2022-02-17T21:59:00Z
# 11  https://i.dailymail.co.uk/1s/2022/02/17/21/543...  2022-02-17T21:49:43Z
# 12  https://nypost.com/wp-content/uploads/sites/2/...  2022-02-17T21:49:00Z
# 13  https://static.politico.com/40/d5/108a5a7941c1...  2022-02-17T21:17:41Z
# 14  https://nypost.com/wp-content/uploads/sites/2/...  2022-02-17T21:12:00Z
# 15  https://cdn.vox-cdn.com/thumbor/abx59ERcj_UWK_...  2022-02-17T21:06:33Z
# 16  https://s.yimg.com/ny/api/res/1.2/46CnldN0pLgY...  2022-02-17T21:05:16Z
# 17  https://www.washingtonpost.com/wp-apps/imrs.ph...  2022-02-17T21:03:00Z
# 18  https://a57.foxnews.com/static.foxbusiness.com...  2022-02-17T20:53:12Z
# 19  https://cdn.cnn.com/cnnnext/dam/assets/2106081...  2022-02-17T20:50:00Z
#
#                                               content
# 0   (CNN)The Senate voted on Thursday to pass a st...
# 1   Both Ukrainian armed forces and separatists co...
# 2   The ruling does not mean that Ms. James will a...
# 3   Image source, Toronto Star via Getty Images\r\...
# 4   Washington and the world are bracing for an im...
# 5   The Los Angeles Rams, quarterback Matthew Staf...
# 6   Embattled Russian figure skater Kamila Valieva...
# 7   It’s no secret that Intel’s enterprise process...
# 8   Tesla Inc. says regulators are harassing Chief...
# 9   California on Thursday laid out a plan that ma...
# 10  Dick Butkus wants to set the record straight b...
# 11  Spotify's deal to secure exclusive rights to T...
# 12  The New York State trooper who claims disgrace...
# 13  The Governor has had many conversations about ...
# 14  Los Angeles Angels staffer Eric Kay was found ...
# 15  Activision Blizzard and Raven Software QA work...
# 16  Wall Streets main benchmarks fell sharply Thur...
# 17  Kristof, who had vowed to challenge the secret...
# 18  Tyson Foods says it's ramping up biosecurity m...
# 19  Washington, DC (CNN)The National Highway Traff...

# %%
top_headlines_df["source"] = top_headlines_df["source"].apply(lambda x: x['name'])

# %%
import helium

top_headlines_df['url'][0]
# Out:
# 'https://www.washingtonpost.com/world/2022/02/14/ukraine-russia-putin-nato/'

# %%
helium.start_chrome(top_headlines_df['url'][0])
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="db94f955e77b787d62734406d095da64")>

# %%
summary_top_headlines_df = top_headlines_df.loc[:, ['source', 'title', 'description']]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\FinTech\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\FinTech\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\FinTech\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'url'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18400/1220109810.py in <module>
#       1 import helium
#       2
# ----> 3 summary_top_headlines_df['url'][0]
#
# ~\anaconda3\envs\FinTech\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\envs\FinTech\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'url'

# %%
# Out:
#                      source  \
# 0       The Washington Post
# 1                  Politico
# 2                   Reuters
# 3            New York Times
# 4                  NFL News
# 5                 USA Today
# 6                  BBC News
# 7       The Washington Post
# 8       The Washington Post
# 9                  Page Six
# 10                      CNN
# 11           New York Times
# 12                  Reuters
# 13            New York Post
# 14      New York Daily News
# 15                 The Hill
# 16                  Variety
# 17           New York Times
# 18  The Wall Street Journal
# 19  The Wall Street Journal
#
#                                                 title  \
# 0   U.S. will close American embassy in Ukraine's ...
# 1   Judge throws out Palin libel case against New ...
# 2   Names of Canada truck convoy donors leaked aft...
# 3   Trump's Long-Time Accounting Firm Cuts Ties Ov...
# 4   Three-round 2022 NFL mock draft 1.0: Five trad...
# 5   Russian Kamila Valieva is cleared to compete a...
# 6   Ukraine crisis: Biden and Johnson say still ho...
# 7   Arbery hate-crimes trial jury selected - The W...
# 8   Accused spy Jonathan Toebbe of Annapolis plead...
# 9   Kanye West sends truckload of roses to Kim Kar...
# 10  Texas sues Meta for collecting facial recognit...
# 11  China Not SpaceX May Be Source of Rocket Crash...
# 12  Everything in place for massive Russian attack...
# 13  Trudeau reportedly eyes emergency powers to en...
# 14  NYC suspect who followed Christina Lee home ch...
# 15  'Mattress Mack' loses record $9.5M Super Bowl ...
# 16  Amy Schumer, Regina Hall, Wanda Sykes Eyed to ...
# 17  Ivan Reitman, Director of ‘Ghostbusters,’ Is D...
# 18  Ukraine’s Capital Awaits a Potential Russian A...
# 19  U.S. Stocks Waver as Investors Weigh Interest ...
#
#                                           description
# 0   All remaining U.S. embassy personnel in Ukrain...
# 1   The ruling came as a Manhattan jury was delibe...
# 2   A website devoted to disseminating leaked data...
# 3   The statements are at the center of two invest...
# 4   Five trades shake up the first round in Chad R...
# 5   The decision made by the Court of Arbitration ...
# 6   The US and UK leaders shared a call after Russ...
# 7   Trial will focus on whether whether Gregory an...
# 8   Jonathan Toebbe pleaded guilty trying to sell ...
# 9   “MY VISION IS KRYSTAL KLEAR,” West, 44, captio...
# 10  Texas is suing Facebook's parent company, Meta...
# 11  The developer of astronomy software who said t...
# 12  France's foreign minister said on Monday that ...
# 13  Canadian Prime Minister Justin Trudeau plans t...
# 14  The victim, despite fighting back against Nash...
# 15  Jim "Mattress Mack" McIngvale, owner of Galler...
# 16  Amy Schumer, Regina Hall and Wanda Sykes are f...
# 17  The filmmaker injected giant marshmallow booge...
# 18  Even as the mood shifts and Kyiv empties of fo...
# 19  Oil prices rise on concern Russian crude suppl...
