# %%
# Initial Imports

import os
from newsapi import NewsApiClient
from datetime import date, timedelta
import pandas as pd
import pdfkit
import flair
news_api_key = os.getenv("news_api_key")

# %%
# Get top headlines for Country USA
    
# newsapi = NewsApiClient(api_key=api_key)
# top_headlines = newsapi.get_top_headlines(country="us",                                   
#                                          language='en')

# %%
def top_headlines():
    newsapi = NewsApiClient(api_key=news_api_key)
    top_articles = newsapi.get_top_headlines(country="us", language='en')

    return top_articles

# %%
top_headlines_df = pd.DataFrame.from_dict(top_headlines()['articles'])

# %%
top_headlines_df
# Out:
#                                                source  \
# 0              {'id': None, 'name': 'New York Times'}
# 1   {'id': 'the-wall-street-journal', 'name': 'The...
# 2              {'id': None, 'name': 'New York Times'}
# 3                      {'id': None, 'name': 'Kotaku'}
# 4              {'id': None, 'name': 'New York Times'}
# 5   {'id': 'business-insider', 'name': 'Business I...
# 6   {'id': 'al-jazeera-english', 'name': 'Al Jazee...
# 7              {'id': 'fox-news', 'name': 'Fox News'}
# 8              {'id': 'buzzfeed', 'name': 'Buzzfeed'}
# 9              {'id': 'the-hill', 'name': 'The Hill'}
# 10  {'id': 'the-washington-post', 'name': 'The Was...
# 11                    {'id': None, 'name': 'TheWrap'}
# 12                       {'id': 'cnn', 'name': 'CNN'}
# 13              {'id': None, 'name': 'NBCSports.com'}
# 14                       {'id': None, 'name': 'CNBC'}
# 15                   {'id': None, 'name': 'Page Six'}
# 16         {'id': None, 'name': 'Prideofdetroit.com'}
# 17             {'id': None, 'name': 'New York Times'}
# 18               {'id': None, 'name': 'CryptoPotato'}
# 19               {'id': None, 'name': 'Fox Business'}
#
#                                      author  \
# 0               Kevin Draper, Chris Buckley
# 1                            Jimmy Vielkind
# 2       Michael S. Schmidt, Luke Broadwater
# 3                              Zack Zwiezen
# 4                               Ben Sisario
# 5                            John L. Dorman
# 6                                Al Jazeera
# 7                               Ryan Gaydos
# 8                             Natasha Jokic
# 9                            Caroline Vakil
# 10                           Amanda Coletta
# 11                            Jeremy Fuster
# 12  Celine Alkhaldi and Lianne Kolirin, CNN
# 13                      Michael David Smith
# 14                             Amelia Lucas
# 15                          Jessica Bennett
# 16                             Erik Schlitt
# 17                             Mujib Mashal
# 18                          George Georgiev
# 19                              Julia Musto
#
#                                                 title  \
# 0   Winter Olympics 2022: Medal Count, Live Update...
# 1   More Than 100,000 People Without Power as Wint...
# 2   Jan. 6 Panel Adopts Prosecution Tactics for It...
# 3     Report: Google Quietly Ditching Stadia - Kotaku
# 4   Joe Rogan Apologizes for ‘Shameful’ Past Use o...
# 5   North Carolina Supreme Court rejects GOP-drawn...
# 6   ‘Widespread damage’ feared as Cyclone Batsirai...
# 7   Roger Goodell addresses 'unacceptable' lack of...
# 8   Gigi Hadid Accidentally Caused A "Commotion" W...
# 9   US troops land near Poland-Ukraine border amid...
# 2   https://static01.nyt.com/images/2022/02/06/us/...  2022-02-05T19:39:46Z
# 3   https://i.kinja-img.com/gawker-media/image/upl...  2022-02-05T18:25:00Z
# 4   https://static01.nyt.com/images/2022/02/05/mul...  2022-02-05T18:11:53Z
# 5   https://i.insider.com/61feb6dffa4f1f0018262ea9...  2022-02-05T18:09:47Z
# 6   https://www.aljazeera.com/wp-content/uploads/2...  2022-02-05T18:00:00Z
# 7   https://static.foxnews.com/foxnews.com/content...  2022-02-05T17:47:36Z
# 8   https://img.buzzfeed.com/buzzfeed-static/stati...  2022-02-05T17:26:52Z
# 9   https://thehill.com/sites/default/files/ca_usm...  2022-02-05T17:25:29Z
# 10  https://www.washingtonpost.com/wp-apps/imrs.ph...  2022-02-05T17:16:45Z
# 11  https://www.thewrap.com/wp-content/uploads/202...  2022-02-05T16:16:04Z
# 12  https://cdn.cnn.com/cnnnext/dam/assets/2202050...  2022-02-05T15:27:00Z
# 13  https://profootballtalk.nbcsports.com/wp-conte...  2022-02-05T15:12:00Z
# 14  https://image.cnbcfm.com/api/v1/image/10701144...  2022-02-05T15:00:01Z
# 15  https://pagesix.com/wp-content/uploads/sites/3...  2022-02-05T15:00:00Z
# 16  https://cdn.vox-cdn.com/thumbor/zvRhdxW620h4rM...  2022-02-05T15:00:00Z
# 17  https://static01.nyt.com/images/2022/02/05/wor...  2022-02-05T14:58:43Z
# 18  https://cryptopotato.com/wp-content/uploads/20...  2022-02-05T14:52:33Z
# 19  https://a57.foxnews.com/static.foxbusiness.com...  2022-02-05T14:23:48Z
#
#                                               content
# 0   Therese Johaug of Norway after winning the 15-...
# 1   More than 100,000 people were without power Sa...
# 2   By comparison, the House select committee that...
# 3   Bad news for all the Stadians out there: A new...
# 4   As pressure has intensified on Spotify and its...
# 5   The North Carolina Supreme Court on Friday str...
# 6   Cyclone Batsirai struck Madagascars eastern re...
# 7   Roger Goodell addressed diversity in the NFLs ...
# 8                                                None
# 9   A Polish military spokesperson announced that ...
# 10  Ottawa Police Chief Peter Sloly, under fire fo...
# 11  Paramount’s “Jackass Forever” has taken over t...
# 12                                               None
# 13  Former University of Pittsburgh quarterback Ke...
# 14  Tequila could soon overtake vodka as America's...
# 15  Candace Owens is backing up Kanye West in his ...
# 16  The 2022 Senior Bowl wraps up on Saturday with...
# 17  Last month, the police arrested Sajad Gul, ano...
# 18  The past 24 hours have been particularly turbu...
# 19  SpaceX and NASA are looking into a parachute i...

# %%
search_terms = []

def get_all_articles(search_term):
    
    newsapi = NewsApiClient(api_key=api_key)
    all_articles = newsapi.get_everything(q=search_term,                                
                                    
    
return all_articles

# %%
articles = []

for term in search_terms:
    
    results = get_top_headlines(term)
    for article in results["articles"]:
        articles.append(article)

# %%
articles_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
news_sentiment_model = flair.models.TextClassifier.load('en-sentiment')
# Out:
# 2022-02-01 18:46:32,086 loading file C:\Users\Airma\.flair\models\sentiment-en-mix-distillbert_4.pt

# %%
# Initialize lists

articles_sentiment = []
articles_confidence = []


# Run Sentiment analysis on collected news sentences

for sentence in articles_df["description"]:
    if sentence.strip() == "":
        articles_sentiment.append("")
        articles_confidence.append("")
        
    else:
        sample = flair.data.Sentence(sentence)
        news_sentiment_model.predict(sample)
        articles_sentiment.append(sample.labels[0].value)
        articles_confidence.append(sample.labels[0].score)

# %%
articles_df['sentiment'] = articles_sentiment
articles_df['confidence'] = articles_confidence

# %%
articles_df.head(5)
# Out:
#                                  source                author  \
# 0  {'id': None, 'name': 'The Guardian'}  As told to Elle Hunt
# 1  {'id': 'reuters', 'name': 'Reuters'}                  None
# 2  {'id': 'reuters', 'name': 'Reuters'}                  None
# 3  {'id': 'reuters', 'name': 'Reuters'}                  None
# 4  {'id': None, 'name': 'Theonion.com'}         Sirhan Sirhan
#
#                                                title  \
# 0  ‘I want Jesus Christ Superstar at my funeral –...
# 1  US beat El Salvador 1-0 in World Cup qualifier...
# 2  Pope blesses those everyone loves to hate - ta...
# 3  Mexico's economy likely entered recession in f...
# 4  Jesus Christ Starts Rival Eternal Paradise Aft...
#
#                                          description  \
# 0  The first single she bought was by Queen and s...
# 1  The United States scraped a 1-0 win over El Sa...
# 2  Pope Francis on Monday encouraged the people e...
# 3  Mexico's economy likely contracted in the last...
# 4  THE COSMOS—In an acrimonious parting of ways t...
#
#                                                  url  \
# 0  https://amp.theguardian.com/music/2022/jan/31/...
# 1  https://www.reuters.com/lifestyle/sports/us-be...
# 2  https://www.reuters.com/world/europe/pope-bles...
# 3  https://www.reuters.com/world/americas/mexicos...
# 4  https://www.theonion.com/jesus-christ-starts-r...
#
#                                           urlToImage           publishedAt  \
# 0  https://i.guim.co.uk/img/media/9fa8f8a7261b414...  2022-01-31T07:00:46Z
# 1  https://www.reuters.com/resizer/eI9E48BnBh9HKf...  2022-01-28T02:28:00Z
# 2  https://www.reuters.com/resizer/fBQAgwFoPYhwnA...  2022-01-31T12:30:00Z
# 3  https://www.reuters.com/pf/resources/images/re...  2022-01-28T16:44:00Z
# 4  https://i.kinja-img.com/gawker-media/image/upl...  2022-01-28T15:14:00Z
#
#                                              content sentiment  confidence
# 0  The last song I streamedHerbie Hancock, Waterm...  NEGATIVE    0.996028
# 1  Jan 27 (Reuters) - The United States scraped a...  NEGATIVE    0.908969
# 2  VATICAN CITY, Jan 31 (Reuters) - Pope Francis ...  NEGATIVE    0.741950
# 3  MEXICO CITY, Jan 28 (Reuters) - Mexico's econo...  NEGATIVE    0.999569
# 4  THE COSMOSIn an acrimonious parting of ways th...  POSITIVE    0.539198
