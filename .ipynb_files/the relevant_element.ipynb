# %%
# Initial Imports

import os
from newsapi import NewsApiClient
from datetime import date, timedelta
import pandas as pd
from fpdf import FPDF
api_key = os.getenv("news_api_key")
from helium_functions import create_wombo_art
import flair
from flair.data import Sentence
import requests
from bs4 import BeautifulSoup

# %%
print(pd.__version__)
# Out:
# 1.3.4

# %%
URL = "https://www.reuters.com/world/europe/ukraine-announces-plan-boost-army-foreign-leaders-rally-2022-02-01/"
r = requests.get(URL)
   
soup = BeautifulSoup(r.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><title>Putin accuses U.S. of trying to lure Russia into war | Reuters</title><meta content="width=device-width, initial-scale=1" name="viewport"/><script>(function(){
#       var current_location = window.location.href;
#
#       if (current_location.indexOf('/info-pages/supported-browsers/') === -1) {
#         var supportFetchApi = 'fetch' in window;
#         var supportCSSGrid = window.CSS && CSS.supports('display', 'grid');
#
#         if (!supportFetchApi && !supportCSSGrid) {
#           window.location.href = '/info-pages/supported-browsers/';
#         }
#       }
# ...

# %%
show_title = ["Lord"] #<----One word related to the show theme
show_theme = ["My help comes from the Lord"]
len(show_theme)
# Out:
# 1

# %%
sentence = Sentence('The grass is green.')
sentence
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7720/470088358.py in <module>
#       1 sentence = Sentence('The grass is green.')
# ----> 2 sentence["Sentence"]
#
# ~\anaconda3\envs\FinTech\lib\site-packages\flair\data.py in __getitem__(self, idx)
#     952
#     953     def __getitem__(self, idx: int) -> Token:
# --> 954         return self.tokens[idx]
#     955
#     956     def __iter__(self):
#
# TypeError: list indices must be integers or slices, not str

# %%
show_theme = ["My help comes from the Lord"]

if len(show_theme) < 100:
    create_wombo_art(show_theme, "Vibrant")
# Out:
# 'My_help_comes_from_the_Lord'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12248/3273829053.py in <module>
# ----> 1 print(pd.__version__)
#
# NameError: name 'pd' is not defined
