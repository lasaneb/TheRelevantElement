# %%
# Initial Imports

import os
from newsapi import NewsApiClient
from datetime import date, timedelta
import pandas as pd
import pdfkit
import flair
api_key = os.getenv("news_api_key")

# %%
# Get top headlines for Country USA
    
newsapi = NewsApiClient(api_key=api_key)
top_articles = newsapi.get_top_headlines(country="us",                                   
                                         language='en')

# %%
top_articles_df = pd.DataFrame.from_dict(top_articles['articles'])

# %%
top_articles_df
# Out:
#                                                source  \
# 0   {'id': 'the-washington-post', 'name': 'The Was...
# 1              {'id': None, 'name': 'New York Times'}
# 2    {'id': None, 'name': 'Minneapolis Star Tribune'}
# 3   {'id': 'the-washington-post', 'name': 'The Was...
# 4                        {'id': 'cnn', 'name': 'CNN'}
# 5   {'id': 'associated-press', 'name': 'Associated...
# 6                        {'id': 'cnn', 'name': 'CNN'}
# 7                        {'id': 'cnn', 'name': 'CNN'}
# 8                 {'id': None, 'name': 'Daily Beast'}
# 9                 {'id': None, 'name': 'The-sun.com'}
# 10                   {'id': None, 'name': 'Barron's'}
# 11              {'id': None, 'name': 'New York Post'}
# 12  {'id': 'the-washington-post', 'name': 'The Was...
# 13                       {'id': 'cnn', 'name': 'CNN'}
# 14                {'id': None, 'name': 'Gizmodo.com'}
# 15           {'id': 'the-verge', 'name': 'The Verge'}
# 16  {'id': 'the-wall-street-journal', 'name': 'The...
# 17                       {'id': 'cnn', 'name': 'CNN'}
# 18  {'id': 'the-wall-street-journal', 'name': 'The...
# 19                       {'id': None, 'name': 'CNBC'}
#
#                                                author  \
# 0                         Josh Dawsey, Felicia Sonmez
# 1                                        Emily Anthes
# 2                  Liz Sawyer, Libor Jany, Paul Walsh
# 3                     Matthew Cappucci, Jason Samenow
# 4                            Lisa Respers France, CNN
# 5                                           Ken Sweet
# 6                      Jack Bantock and Coy Wire, CNN
# 7                                        Sean Lyngaas
# 8                                       Neel V. Patel
# 9                                         Katie Davis
# 10                  Jacob Sonenshine, and Jack Denton
# 11                                   Jenna Lemoncelli
# 12                                         Liz Clarke
# 13  Alta Spells, Pamela Kirkland and Dakin Andone,...
# 14                                     George Dvorsky
# 15                                         Jon Porter
# 16              Sarah Chaney Cambon, Gabriel T. Rubin
# 17  By <a href="/profiles/adrienne-vogt">Adrienne ...
# 18  Yaroslav Trofimov, Anastasia Vlasova for The W...
# 19                                      Pippa Stevens
#
#                                                 title  \
# 0   RNC votes to condemn Cheney, Kinzinger for ser...
# 1   Covid-19, Vaccine and Testing News: Live Updat...
# 2   Minneapolis police insisted on 'no knock' warr...
# 3   Winter storm brings ice, snow, power outages a...
# 4   Kim Kardashian calls out Kanye West's 'obsessi...
# 5   COVID falling in 49 of 50 states as deaths nea...
# 6   Nathan Chen: Balancing act of Yale student and...
# 7   Suspected Chinese hackers hit News Corp with '...
# 8   New NASA Chandra X-Ray Photos Hint at Future A...
# 9   How China is using Winter Olympics to whitewas...
# 10  Stock Market Today: Payrolls Surge, Dow Wavers...
# 11  Bill Belichick's Giants 'influence' on coachin...
# 12  Daniel Snyder could block release of probe det...
# 13  Travis McMichael will be tried on federal hate...
# 14  Webb Space Telescope Successfully Spots Its Fi...
# 15  Rockstar Games officially confirms GTA6 is in ...
# 16  U.S. Jobs Growth Surged by 467,000 in January ...
# 17  The latest on the coronavirus pandemic and the...
# 18  Dismal Russian Record in Occupied Eastern Ukra...
# 19  Biden extends Trump-era solar tariffs, with se...
#
#                                           description  \
# 0   In addition to Friday’s formal censure at the ...
# 1   Consistently wearing N95s or their counterpart...
# 2   Officers were at the downtown Minneapolis apar...
# 3   A thick glaze of ice has left thousands in the...
# 4   In a rare public rebuke,Kim Kardashian has pus...
# 5   With the brutal omicron wave rapidly loosening...
# 6   At just 10 years old, Nathan Chen predicted in...
# 7   News Corp suffered a "persistent cyberattack" ...
# 8   It’s just a taste of the kind of regular eye-c...
# 9
# 10  Oil prices continued their seemingly inexorabl...
# 11  In a Thursday interview on NPR’s “The Limits w...
# 12  The House Democrats investigating the NFL's ha...
# 13  Travis McMichael will stand trial on federal h...
# 14  HD 84406 will go down in history as the first ...
# 15  A new entry in the Grand Theft Auto series is ...
# 16  Unemployment rate ticked up to 4%, with more p...
# 17  The Beijing Olympics Committee has identified ...
# 18  The areas, once engines of the Ukrainian econo...
# 19  The Biden administration said Friday that it w...
#
#                                                   url  \
# 0   https://www.washingtonpost.com/nation/2022/02/...
# 1   https://www.nytimes.com/live/2022/02/04/world/...
# 2   https://www.startribune.com/freeman-ellison-to...
# 3   https://www.washingtonpost.com/weather/2022/02...
# 4   https://www.cnn.com/2022/02/04/entertainment/k...
# 5   https://apnews.com/76dc452fb7263612529e09eb23b...
# 6   https://www.cnn.com/2022/02/04/sport/nathan-ch...
# 7   https://www.cnn.com/2022/02/04/tech/news-corp-...
# 8   https://www.thedailybeast.com/new-nasa-chandra...
# 9   https://www.the-sun.com/news/4614277/china-win...
# 10  https://www.barrons.com/articles/stock-market-...
# 11  https://nypost.com/2022/02/04/brian-flores-cla...
# 12  https://www.washingtonpost.com/sports/2022/02/...
# 13  https://www.cnn.com/2022/02/04/us/travis-mcmic...
# 14  https://gizmodo.com/james-webb-space-telescop-...
# 15  https://www.theverge.com/2022/2/4/22917783/roc...
# 16  https://www.wsj.com/articles/january-jobs-repo...
# 17  https://www.cnn.com/world/live-news/omicron-va...
# 18  https://www.wsj.com/articles/dismal-russian-re...
# 19  https://www.cnbc.com/2022/02/04/president-bide...
#
#                                            urlToImage           publishedAt  \
# 0   https://www.washingtonpost.com/wp-apps/imrs.ph...  2022-02-04T18:38:17Z
# 1   https://static01.nyt.com/images/2022/02/04/mul...  2022-02-04T18:36:39Z
# 2   https://chorus.stimg.co/23217100/1door.jpg?h=6...  2022-02-04T17:48:45Z
# 3   https://www.washingtonpost.com/wp-apps/imrs.ph...  2022-02-04T17:36:27Z
# 4   https://cdn.cnn.com/cnnnext/dam/assets/2106041...  2022-02-04T17:36:00Z
# 5   https://storage.googleapis.com/afs-prod/media/...  2022-02-04T17:32:21Z
# 6   https://cdn.cnn.com/cnnnext/dam/assets/2202031...  2022-02-04T17:09:00Z
# 7   https://cdn.cnn.com/cnnnext/dam/assets/2201181...  2022-02-04T16:58:00Z
# 8   https://img.thedailybeast.com/image/upload/c_c...  2022-02-04T16:51:38Z
# 9   https://www.the-sun.com/wp-content/uploads/sit...  2022-02-04T16:48:00Z
# 10        https://images.barrons.com/im-473530/social  2022-02-04T16:42:00Z
# 11  https://nypost.com/wp-content/uploads/sites/2/...  2022-02-04T16:29:00Z
# 12  https://www.washingtonpost.com/wp-apps/imrs.ph...  2022-02-04T16:11:50Z
# 13  https://cdn.cnn.com/cnnnext/dam/assets/2201311...  2022-02-04T16:05:00Z
# 14  https://i.kinja-img.com/gawker-media/image/upl...  2022-02-04T16:00:00Z
# 15  https://cdn.vox-cdn.com/thumbor/IeRqIK_qpZJz5C...  2022-02-04T15:59:32Z
# 16            https://images.wsj.net/im-479699/social  2022-02-04T15:46:00Z
# 17  https://dynaimage.cdn.cnn.com/cnn/digital-imag...  2022-02-04T15:44:00Z
# 18            https://images.wsj.net/im-479433/social  2022-02-04T15:24:00Z
# 19  https://image.cnbcfm.com/api/v1/image/10241778...  2022-02-04T15:07:08Z
#
#                                               content
# 0   In addition to Fridays formal censure at the p...
# 1   Donald Kauerauf, Missouris top health official...
# 2   St. Paul police applied for a standard search ...
# 3   On Friday, the freezing rain was causing new p...
# 4                                                None
# 5   With the brutal omicron wave rapidly loosening...
# 6                                                None
# 7   New York (CNN Business)News Corp suffered a "p...
# 8   NASA just released a new gallery of images tha...
# 9   CHINA has been accused of using the Winter Oly...
# 10  Stocks were mostly rising on Friday. The surpr...
# 11  Former Dolphins coach Brian Flores said he bel...
# 12  The existence of the document, which was obtai...
# 13  (CNN)Travis McMichael will stand trial on fede...
# 14  A major milestone has been achieved in the dep...
# 15  GTAVs current-gen patches will arrive on March...
# 16  Employers hired workers at a swift pace in Jan...
# 17  The Beijing Olympic Committee has reported 21 ...
# 18  STANYTSIA LUHANSKA, UkraineThe Russian-control...
# 19  The Biden administration said Friday that it w...

# %%
search_terms = []

def get_all_articles(search_term):
    
    newsapi = NewsApiClient(api_key=api_key)
    all_articles = newsapi.get_everything(q=search_term,                                
                                    
    
return all_articles

# %%
articles = []

for term in search_terms:
    
    results = get_top_headlines(term)
    for article in results["articles"]:
        articles.append(article)

# %%
articles_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
news_sentiment_model = flair.models.TextClassifier.load('en-sentiment')
# Out:
# 2022-02-01 18:46:32,086 loading file C:\Users\Airma\.flair\models\sentiment-en-mix-distillbert_4.pt

# %%
# Initialize lists

articles_sentiment = []
articles_confidence = []


# Run Sentiment analysis on collected news sentences

for sentence in articles_df["description"]:
    if sentence.strip() == "":
        articles_sentiment.append("")
        articles_confidence.append("")
        
    else:
        sample = flair.data.Sentence(sentence)
        news_sentiment_model.predict(sample)
        articles_sentiment.append(sample.labels[0].value)
        articles_confidence.append(sample.labels[0].score)

# %%
articles_df['sentiment'] = articles_sentiment
articles_df['confidence'] = articles_confidence

# %%
articles_df.head(5)
# Out:
#                                  source                author  \
# 0  {'id': None, 'name': 'The Guardian'}  As told to Elle Hunt
# 1  {'id': 'reuters', 'name': 'Reuters'}                  None
# 2  {'id': 'reuters', 'name': 'Reuters'}                  None
# 3  {'id': 'reuters', 'name': 'Reuters'}                  None
# 4  {'id': None, 'name': 'Theonion.com'}         Sirhan Sirhan
#
#                                                title  \
# 0  ‘I want Jesus Christ Superstar at my funeral –...
# 1  US beat El Salvador 1-0 in World Cup qualifier...
# 2  Pope blesses those everyone loves to hate - ta...
# 3  Mexico's economy likely entered recession in f...
# 4  Jesus Christ Starts Rival Eternal Paradise Aft...
#
#                                          description  \
# 0  The first single she bought was by Queen and s...
# 1  The United States scraped a 1-0 win over El Sa...
# 2  Pope Francis on Monday encouraged the people e...
# 3  Mexico's economy likely contracted in the last...
# 4  THE COSMOS—In an acrimonious parting of ways t...
#
#                                                  url  \
# 0  https://amp.theguardian.com/music/2022/jan/31/...
# 1  https://www.reuters.com/lifestyle/sports/us-be...
# 2  https://www.reuters.com/world/europe/pope-bles...
# 3  https://www.reuters.com/world/americas/mexicos...
# 4  https://www.theonion.com/jesus-christ-starts-r...
#
#                                           urlToImage           publishedAt  \
# 0  https://i.guim.co.uk/img/media/9fa8f8a7261b414...  2022-01-31T07:00:46Z
# 1  https://www.reuters.com/resizer/eI9E48BnBh9HKf...  2022-01-28T02:28:00Z
# 2  https://www.reuters.com/resizer/fBQAgwFoPYhwnA...  2022-01-31T12:30:00Z
# 3  https://www.reuters.com/pf/resources/images/re...  2022-01-28T16:44:00Z
# 4  https://i.kinja-img.com/gawker-media/image/upl...  2022-01-28T15:14:00Z
#
#                                              content sentiment  confidence
# 0  The last song I streamedHerbie Hancock, Waterm...  NEGATIVE    0.996028
# 1  Jan 27 (Reuters) - The United States scraped a...  NEGATIVE    0.908969
# 2  VATICAN CITY, Jan 31 (Reuters) - Pope Francis ...  NEGATIVE    0.741950
# 3  MEXICO CITY, Jan 28 (Reuters) - Mexico's econo...  NEGATIVE    0.999569
# 4  THE COSMOSIn an acrimonious parting of ways th...  POSITIVE    0.539198
