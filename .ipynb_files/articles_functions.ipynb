# %%
# Initial Imports

import os
from newsapi import NewsApiClient
from datetime import date, timedelta
import pandas as pd
import pdfkit
import flair
api_key = os.getenv("news_api_key")

# %%
# Get top headlines for Country USA
    
newsapi = NewsApiClient(api_key=api_key)
top_articles = newsapi.get_top_headlines(country="us",                                   
                                         language='en')

# %%
top_articles_df = pd.DataFrame.from_dict(top_articles['articles'])

# %%
top_articles_df
# Out:
#                                                source  \
# 0              {'id': None, 'name': 'New York Times'}
# 1                        {'id': 'cnn', 'name': 'CNN'}
# 2              {'id': None, 'name': 'New York Times'}
# 3                        {'id': None, 'name': 'ESPN'}
# 4              {'id': 'fox-news', 'name': 'Fox News'}
# 5         {'id': None, 'name': 'Yahoo Entertainment'}
# 6                  {'id': None, 'name': 'Daily Mail'}
# 7              {'id': 'fox-news', 'name': 'Fox News'}
# 8                     {'id': None, 'name': 'Cdc.gov'}
# 9   {'id': 'the-washington-post', 'name': 'The Was...
# 10                 {'id': None, 'name': 'Daily Mail'}
# 11                       {'id': 'cnn', 'name': 'CNN'}
# 12               {'id': 'reuters', 'name': 'Reuters'}
# 13             {'id': 'engadget', 'name': 'Engadget'}
# 14                       {'id': 'cnn', 'name': 'CNN'}
# 15  {'id': 'associated-press', 'name': 'Associated...
# 16               {'id': 'reuters', 'name': 'Reuters'}
# 17                       {'id': 'cnn', 'name': 'CNN'}
# 18                {'id': None, 'name': 'Daily Beast'}
# 19                       {'id': 'cnn', 'name': 'CNN'}
#
#                                                author  \
# 0                      Jesus Jiménez, Sophie Kasakove
# 1   Jeremy Herb, Barbara Starr, Oren Liebermann, E...
# 2                Vivian Yee, Aida Alami, Dan Bilefsky
# 3                                      Tisha Thompson
# 4                                      Fox News Staff
# 5                                         Nancy Lapid
# 6                                       Ryan Morrison
# 7                                    Paul Steinhauser
# 8                                                 CDC
# 9                         Emily Rauhala, Andrew Jeong
# 10                                       George Stark
# 11                              Lauren del Valle, CNN
# 12                                               None
# 13  https://www.engadget.com/about/editors/igor-bo...
# 14                           Lisa Respers France, CNN
# 15                                          Ken Sweet
# 16                                               None
# 17                                       Sean Lyngaas
# 18                                      Neel V. Patel
# 19  Alta Spells, Pamela Kirkland and Dakin Andone,...
#
#                                                 title  \
# 0   A Tenacious Winter Storm Moves Across the Nort...
# 1   Pentagon says deadly Afghan airport attack was...
# 2   Rescuers Work to Free Child Stuck in Well in M...
# 3   Washington Commanders owner Daniel Snyder has ...
# 4   Sen. Blackburn slams Pelosi for 'unseemly' adv...
# 5   Alzheimer's-like changes found in COVID patien...
# 6   NASA's James Webb Space Telescope captures its...
# 7   Republican National Committee overwhelming vot...
# 8   Effectiveness of Face Mask or Respirator Use i...
# 9   Putin meets Xi Jinping as US warns of Russian ...
# 10  Robin Thicke and Ken Jeong are seen back on se...
# 11  Michael Avenatti jury tells judge that one jur...
# 3   https://a.espncdn.com/combiner/i?img=%2Fphoto%...  2022-02-04T19:30:00Z
# 4   https://cf-images.us-east-1.prod.boltdns.net/v...  2022-02-04T19:22:11Z
# 5   https://s.yimg.com/uu/api/res/1.2/zxdVVpTwnCPN...  2022-02-04T19:07:38Z
# 6   https://i.dailymail.co.uk/1s/2022/02/04/18/535...  2022-02-04T18:38:02Z
# 7   https://static.foxnews.com/foxnews.com/content...  2022-02-04T18:34:49Z
# 8   https://www.cdc.gov/mmwr/volumes/71/wr/social-...  2022-02-04T18:31:24Z
# 9   https://www.washingtonpost.com/wp-apps/imrs.ph...  2022-02-04T18:29:31Z
# 10  https://i.dailymail.co.uk/1s/2022/02/04/17/537...  2022-02-04T18:01:11Z
# 11  https://cdn.cnn.com/cnnnext/dam/assets/2201251...  2022-02-04T18:00:00Z
# 12  https://www.reuters.com/resizer/XB5mjB59GBaVs0...  2022-02-04T17:40:00Z
# 13  https://s.yimg.com/os/creatr-uploaded-images/2...  2022-02-04T17:37:30Z
# 14  https://cdn.cnn.com/cnnnext/dam/assets/2106041...  2022-02-04T17:36:00Z
# 15  https://storage.googleapis.com/afs-prod/media/...  2022-02-04T17:32:21Z
# 16  https://www.reuters.com/resizer/EY312lv_TAg9RT...  2022-02-04T17:08:00Z
# 17  https://cdn.cnn.com/cnnnext/dam/assets/2201181...  2022-02-04T16:58:00Z
# 18  https://img.thedailybeast.com/image/upload/c_c...  2022-02-04T16:51:38Z
# 19  https://cdn.cnn.com/cnnnext/dam/assets/2201311...  2022-02-04T16:05:00Z
#
#                                               content
# 0   Buffalo, N.Y., and northern Vermont could see ...
# 1   (CNN)The top US general in the Middle East sai...
# 2   CAIRO Rescuers working day and night were raci...
# 3   The NFL may not be able to publicly release th...
# 4   Sen. Marsha Blackburn, R-Tenn., criticized Hou...
# 5   By Nancy Lapid\r\n(Reuters) - The following is...
# 6   NASA's James Webb Space Telescope has captured...
# 7   The Republican National Committee (RNC) took a...
# 8   Kristin L. Andrejko1,2,*; Jake M. Pry, PhD2,*;...
# 9   They expressed opposition to NATO enlargement ...
# 10  Robin Thicke and Ken Jeong have been pictured ...
# 11  New York (CNN)The jury in the Michael Avenatti...
# 12  Feb 4 (Reuters) - The Nasdaq rose in choppy tr...
# 13  In a few short days, Samsung will host its fir...
# 14                                               None
# 15  With the brutal omicron wave rapidly loosening...
# 16  BEIJING, Feb 4 (Reuters) - Chinese President X...
# 17  New York (CNN Business)News Corp suffered a "p...
# 18  NASA just released a new gallery of images tha...
# 19  (CNN)Travis McMichael will stand trial on fede...

# %%
search_terms = []

def get_all_articles(search_term):
    
    newsapi = NewsApiClient(api_key=api_key)
    all_articles = newsapi.get_everything(q=search_term,                                
                                    
    
return all_articles

# %%
articles = []

for term in search_terms:
    
    results = get_top_headlines(term)
    for article in results["articles"]:
        articles.append(article)

# %%
articles_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
news_sentiment_model = flair.models.TextClassifier.load('en-sentiment')
# Out:
# 2022-02-01 18:46:32,086 loading file C:\Users\Airma\.flair\models\sentiment-en-mix-distillbert_4.pt

# %%
# Initialize lists

articles_sentiment = []
articles_confidence = []


# Run Sentiment analysis on collected news sentences

for sentence in articles_df["description"]:
    if sentence.strip() == "":
        articles_sentiment.append("")
        articles_confidence.append("")
        
    else:
        sample = flair.data.Sentence(sentence)
        news_sentiment_model.predict(sample)
        articles_sentiment.append(sample.labels[0].value)
        articles_confidence.append(sample.labels[0].score)

# %%
articles_df['sentiment'] = articles_sentiment
articles_df['confidence'] = articles_confidence

# %%
articles_df.head(5)
# Out:
#                                  source                author  \
# 0  {'id': None, 'name': 'The Guardian'}  As told to Elle Hunt
# 1  {'id': 'reuters', 'name': 'Reuters'}                  None
# 2  {'id': 'reuters', 'name': 'Reuters'}                  None
# 3  {'id': 'reuters', 'name': 'Reuters'}                  None
# 4  {'id': None, 'name': 'Theonion.com'}         Sirhan Sirhan
#
#                                                title  \
# 0  ‘I want Jesus Christ Superstar at my funeral –...
# 1  US beat El Salvador 1-0 in World Cup qualifier...
# 2  Pope blesses those everyone loves to hate - ta...
# 3  Mexico's economy likely entered recession in f...
# 4  Jesus Christ Starts Rival Eternal Paradise Aft...
#
#                                          description  \
# 0  The first single she bought was by Queen and s...
# 1  The United States scraped a 1-0 win over El Sa...
# 2  Pope Francis on Monday encouraged the people e...
# 3  Mexico's economy likely contracted in the last...
# 4  THE COSMOS—In an acrimonious parting of ways t...
#
#                                                  url  \
# 0  https://amp.theguardian.com/music/2022/jan/31/...
# 1  https://www.reuters.com/lifestyle/sports/us-be...
# 2  https://www.reuters.com/world/europe/pope-bles...
# 3  https://www.reuters.com/world/americas/mexicos...
# 4  https://www.theonion.com/jesus-christ-starts-r...
#
#                                           urlToImage           publishedAt  \
# 0  https://i.guim.co.uk/img/media/9fa8f8a7261b414...  2022-01-31T07:00:46Z
# 1  https://www.reuters.com/resizer/eI9E48BnBh9HKf...  2022-01-28T02:28:00Z
# 2  https://www.reuters.com/resizer/fBQAgwFoPYhwnA...  2022-01-31T12:30:00Z
# 3  https://www.reuters.com/pf/resources/images/re...  2022-01-28T16:44:00Z
# 4  https://i.kinja-img.com/gawker-media/image/upl...  2022-01-28T15:14:00Z
#
#                                              content sentiment  confidence
# 0  The last song I streamedHerbie Hancock, Waterm...  NEGATIVE    0.996028
# 1  Jan 27 (Reuters) - The United States scraped a...  NEGATIVE    0.908969
# 2  VATICAN CITY, Jan 31 (Reuters) - Pope Francis ...  NEGATIVE    0.741950
# 3  MEXICO CITY, Jan 28 (Reuters) - Mexico's econo...  NEGATIVE    0.999569
# 4  THE COSMOSIn an acrimonious parting of ways th...  POSITIVE    0.539198
